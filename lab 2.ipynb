# %%
# Приклад аналізу часових даних (просто структура коду)
import pandas as pd
import matplotlib.pyplot as plt

# Завантаження часових даних (приклад, вам потрібно завантажити власні дані)
data = pd.read_csv('C:/Users/06650/Downloads/Electric_Production.csv')

# Перегляд перших рядків та статистики
print(data.head())
print(data.describe())

# Візуалізація часового ряду (приклад, вам потрібно адаптувати до свого набору даних)
plt.figure(figsize=(12, 6))
plt.plot(data['DATE'], data['IPG2211A2N'], label='Часовий ряд')
plt.xlabel('Дата')
plt.ylabel('Значення')
plt.legend()
plt.title('Аналіз часового ряду')
plt.show()

# Аналіз тренду, сезонності та ін.
# Використовуйте відповідні методи аналізу часових рядів для отримання інсайтів.
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151
#        IPG2211A2N
# count  397.000000
# mean    88.847218
# std     15.387834
# min     55.315100
# 25%     77.105200
# 50%     89.779500
# 75%    100.524400
# max    129.404800
